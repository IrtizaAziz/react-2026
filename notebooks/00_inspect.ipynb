# %% [markdown]
# # Inspect organizer data
#
# Run only after reading the complete problem statement and Evaluation. Audit observations are diagnostics and do not configure training. Check the official sample, time/group/entity structure, and potential leakage before selecting validation.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').is_dir() and (ROOT.parent / 'src').is_dir():
    ROOT = ROOT.parent
if not (ROOT / 'src').is_dir():
    raise ValueError('Open this template from the local repository. For Kaggle, use the self-contained exported notebook.')
sys.path.insert(0, str(ROOT))

# %%
from src.audit import audit
from src.config import load_config
config_path = ROOT / 'config.json'
config = load_config(config_path if config_path.exists() else None)
audit(ROOT, config=config)

# %% [markdown]
# Record verified facts in CURRENT_STATE.md and COMPETITION.md. Keep target/metric/CV unresolved when evidence is insufficient. No test labels may enter fitting, validation, or feature selection.
