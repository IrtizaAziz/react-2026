# %% [markdown]
# # Final candidate preparation
#
# This is the local preparation template. The exporter below produces a separate self-contained notebook from saved experiment source, not the changing checkout. Up to two final candidates are human selections; public scores are secondary evidence.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if not (ROOT / 'src').is_dir() and (ROOT.parent / 'src').is_dir():
    ROOT = ROOT.parent
if not (ROOT / 'src').is_dir():
    raise ValueError('Open this template from the local repository. For Kaggle, use the self-contained exported notebook.')
sys.path.insert(0, str(ROOT))

# %%
EXPERIMENT = None
if not EXPERIMENT:
    raise ValueError('Choose a reproducible candidate explicitly before exporting.')
from src.export_notebook import export_notebook
exported = export_notebook(ROOT, EXPERIMENT)
print(exported)

# %% [markdown]
# Open the exported notebook privately on Kaggle, map the organizer file paths, inspect recorded dependencies, run training and inference, and verify exact artifacts. Any pretrained model must be loaded in that notebook, with source/exact name disclosed in the method summary. Save Version and record its exact version URL in the ledger, report, and submission sidecar. Share only as instructed by the organizers. CSV upload and final selections are separate human actions.
